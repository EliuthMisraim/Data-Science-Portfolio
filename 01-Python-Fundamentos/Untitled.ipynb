# %% [markdown]
# # 🔁 Tema 3: Ciclos `for` y `while`
#
# ¡Bienvenido/a al tercer tema!
#
# Hasta ahora, nuestro código se ejecutaba de arriba hacia abajo una sola vez. En este tema aprenderemos sobre **bucles** (o ciclos), estructuras fundamentales que nos permiten repetir bloques de código múltiples veces, lo cual es la verdadera magia de la automatización en la programación.
#
# ## 🚀 Contenido del Cuaderno
#
# 1. **La instrucción `while`:** Ciclos controlados por condiciones.
# 2. **Ejercicio Práctico (`while`):** Validador de potencias de 2.
# 3. **La instrucción `for`:** Iteración sobre secuencias o rangos definidos.
# 4. **Ejercicio Práctico (`for`):** Calculadora de Factoriales.
# 5. **Nivel Pro:** Refactorización de código eliminando variables globales.
#
# ---
# > **Instrucciones:** Ejecuta las celdas de código (Code) paso a paso para ver los resultados. Lee las celdas de texto (Markdown) para entender la lógica detrás de cada operación.
