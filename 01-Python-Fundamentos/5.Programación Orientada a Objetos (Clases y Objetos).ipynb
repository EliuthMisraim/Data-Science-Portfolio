# %% [markdown]
# # 📦 Tema 5: Programación Orientada a Objetos (Clases y Objetos)
#
# ¡Bienvenido/a al paradigma que cambiará tu forma de programar!
#
# Hasta ahora hemos escrito código de manera "estructurada" (paso a paso). En este tema, daremos el salto a la **Programación Orientada a Objetos (POO)**. Este enfoque nos permite modelar cosas del mundo real llevándolas al código, empaquetando **datos** (atributos) y **comportamientos** (métodos) en una sola entidad.
#
# ## 🚀 Contenido del Cuaderno
#
# 1. **Definición de Clases y Objetos:** La diferencia entre el molde y el producto.
# 2. **Práctica de Clases y Constructores:** Creando nuestras primeras entidades y entendiendo `self`.
# 3. **Aplicaciones avanzadas:** El poder del método `__init__`.
# 4. **Ejercicio Práctico:** Conversor de Números Romanos a Enteros.
# 5. **Nivel Pro:** Documentación de clases e instanciación segura.
#
# ---
# > **Instrucciones:** Ejecuta las celdas de código (Code) paso a paso para ver los resultados. Lee las celdas de texto (Markdown) para entender la lógica detrás de cada operación.

# %% [markdown]
# ## 1. Define clases, objetos y constructores en Python
#
#
#
# Para entender la POO, la mejor analogía es la construcción de una casa:
# * **La Clase (Class):** Es el *plano arquitectónico*. No es una casa real, es un diseño que dice cuántas puertas y ventanas habrá.
# * **El Objeto (Object):** Es la *casa construida*. Puedes construir múltiples casas (objetos) a partir del mismo plano (clase). Cada casa tendrá sus propios colores o dueños, pero comparten la misma estructura.
#
# En Python, un objeto contiene:
# * **Atributos:** Son variables que guardan características del objeto (Ej. `color = "rojo"`).
# * **Métodos:** Son funciones que pertenecen al objeto y definen lo que puede hacer (Ej. `abrir_puerta()`).

# %%
# 💡 Ejemplo básico: El Plano (Clase) y la Casa (Objeto)

# 1. Definimos la Clase (por convención, sus nombres empiezan con Mayúscula)
class Perro:
    # Atributo general
    especie = "Canino"
    
    # Método (Comportamiento)
    def ladrar(self):
        return "¡Guau, guau!"

# 2. Creamos el Objeto (Instanciación)
mi_mascota = Perro()

# 3. Usamos el objeto
print(f"Mi mascota es de la especie: {mi_mascota.especie}")
print(f"Y hace: {mi_mascota.ladrar()}")
# Out:
# Mi mascota es de la especie: Canino
# Y hace: ¡Guau, guau!

# %% [markdown]
# ## 2. Practica y Usa Constructores (`__init__` y `self`)
#
# Las casas creadas con el plano anterior son todas idénticas. ¿Qué pasa si queremos que al crear el objeto, este nazca con características únicas? Aquí entra el **Constructor**.
#
# El constructor en Python es un método especial llamado `__init__`. Se ejecuta automáticamente en el momento exacto en que creas (instancias) un objeto nuevo.
#
# **¿Y qué es `self`?**
# `self` es una palabra obligatoria en los métodos de las clases. Significa "a mí mismo". Es la forma en que el objeto puede acceder a sus propios atributos y modificarlos.

# %%
# 💡 Ejemplo con Constructor: Dando vida propia a los objetos

class CuentaBancaria:
    # El Constructor (__init__) recibe los datos iniciales
    def __init__(self, titular, saldo_inicial):
        self.titular = titular       # "El titular de ESTE objeto es..."
        self.saldo = saldo_inicial   # "El saldo de ESTE objeto es..."
        
    def mostrar_info(self):
        return f"La cuenta de {self.titular} tiene ${self.saldo} MXN."

# Ahora, al instanciar, DEBEMOS pasarle los argumentos
cuenta_ana = CuentaBancaria("Ana", 5000)
cuenta_carlos = CuentaBancaria("Carlos", 150)

print(cuenta_ana.mostrar_info())
print(cuenta_carlos.mostrar_info())
# Out:
# La cuenta de Ana tiene $5000 MXN.
# La cuenta de Carlos tiene $150 MXN.

# %% [markdown]
# ---
# ## 📝 Ejercicio Práctico: Conversor de Número Romano a Entero
#
# Ahora combinaremos Clases, Diccionarios y Ciclos en un solo problema profesional.
#
# **Objetivo:**
# Escriba una clase denominada `Conversion` que permita la conversión de un número romano a un número entero a través de un método llamado `romano_entero`.
#
# **Valores Base:**
# * "I" = 1, "V" = 5, "X" = 10, "L" = 50, "C" = 100, "D" = 500, "M" = 1000
#
# **Lógica Especial de los Números Romanos:**
# Normalmente, los valores se suman de izquierda a derecha (Ej. `VIII` = 5 + 1 + 1 + 1 = 8).
# Sin embargo, **si un símbolo de menor valor está antes de un símbolo de mayor valor**, se *resta* (Ej. `IV` = 5 - 1 = 4; `XLIV` = 44).

# %%
class Conversion:
    # Constructor: Inicializa el diccionario de valores apenas se crea el objeto
    def __init__(self):
        self.valores = {
            'I': 1,
            'V': 5,
            'X': 10,
            'L': 50,
            'C': 100,
            'D': 500,
            'M': 1000
        }

    # Método principal de conversión
    def romano_entero(self, romano):
        entero = 0
        i = 0
        
        while i < len(romano):
            # Condición clave: Si el valor actual es menor que el siguiente, se restan
            if i + 1 < len(romano) and self.valores[romano[i]] < self.valores[romano[i + 1]]:
                entero += self.valores[romano[i + 1]] - self.valores[romano[i]]
                i += 2  # Damos un salto doble porque ya procesamos 2 letras
            else:
                # Caso normal: simplemente sumamos
                entero += self.valores[romano[i]]
                i += 1  # Pasamos a la siguiente letra
                
        return entero

# --- Ejemplo de uso ---
# 1. Instanciamos el objeto
numero = Conversion()

# 2. Invocamos su método e imprimimos resultados
print(f"MMMCMLXXXVI -> {numero.romano_entero('MMMCMLXXXVI')}")  # Salida esperada: 3986
print(f"VIII -> {numero.romano_entero('VIII')}")                # Salida esperada: 8
print(f"XLIV -> {numero.romano_entero('XLIV')}")                # Salida esperada: 44
print(f"CLXX -> {numero.romano_entero('CLXX')}")                # Salida esperada: 170
print(f"MCDL -> {numero.romano_entero('MCDL')}")                # Salida esperada: 1450
# Out:
# MMMCMLXXXVI -> 3986
# VIII -> 8
# XLIV -> 44
# CLXX -> 170
# MCDL -> 1450

# %% [markdown]
# ## 🔍 Explicación del Algoritmo
#
# Este ejercicio es un clásico en las entrevistas técnicas de programación. Nuestro objeto `Conversion` lo resuelve de la siguiente manera:
#
# 1.  **El Constructor (`__init__`)**: Actúa como la memoria de nuestro conversor. Guarda un diccionario que asocia cada letra romana con su valor matemático. Al hacerlo en el constructor, garantizamos que cada objeto instanciado conozca las reglas del juego de inmediato.
# 2.  **El Ciclo `while`**: Recorremos la cadena de texto de izquierda a derecha usando un índice `i`.
# 3.  **La Condición "Look-Ahead" (Mirar hacia adelante)**: La magia del código ocurre en la línea `if i + 1 < len(romano)`.
#     * Primero, verifica que no estemos en la última letra.
#     * Luego, compara el valor de la letra actual con la siguiente. Si la letra actual vale menos (como la `I` antes de la `V`), significa que es una resta.
#     * Si hay resta, procesa ambos valores (`V - I`) y avanza el índice dos espacios (`i += 2`).

# %% [markdown]
# ## 🚀 Nivel Pro: Código Robusto y Documentado
#
# En el código anterior, ¿qué pasaría si un usuario escribe en minúsculas (`'viii'`)? El programa fallaría buscando `'v'` en el diccionario. En la versión "Pro", vamos a proteger a nuestro Objeto aplicando lo siguiente:
#
# * **Type Hinting:** Para saber qué tipos de datos entran y salen.
# * **Limpieza de Datos (`.upper()`):** Para asegurar que nuestro diccionario siempre funcione.
# * **Docstrings:** Para que la clase sea fácil de entender por otros desarrolladores.

# %%
class ConversorRomanoPro:
    """
    Clase encargada de interpretar y convertir números de la antigua Roma
    a valores enteros modernos.
    """
    
    def __init__(self):
        """Inicializa el mapa de equivalencias matemáticas."""
        self._valores = {
            'I': 1, 'V': 5, 'X': 10, 'L': 50,
            'C': 100, 'D': 500, 'M': 1000
        }

    def romano_entero(self, romano: str) -> int:
        """
        Convierte una cadena de texto de números romanos a enteros.
        Ignora espacios en blanco y acepta minúsculas.
        
        Args:
            romano (str): El número romano a convertir.
            
        Returns:
            int: El valor en formato decimal.
        """
        # Limpieza de datos preventiva
        romano_limpio = romano.upper().strip()
        
        entero = 0
        i = 0
        
        while i < len(romano_limpio):
            # Evaluamos la regla de sustracción (Ej. IV, IX, XL)
            if i + 1 < len(romano_limpio) and self._valores[romano_limpio[i]] < self._valores[romano_limpio[i + 1]]:
                entero += self._valores[romano_limpio[i + 1]] - self._valores[romano_limpio[i]]
                i += 2
            else:
                entero += self._valores[romano_limpio[i]]
                i += 1
                
        return entero

# --- Automatización de Pruebas ---
if __name__ == "__main__":
    print("=== 🏛️ Conversor Romano Pro ===")
    
    # Instanciamos el objeto
    traductor = ConversorRomanoPro()
    
    # Probamos con casos normales, minúsculas y espacios accidentales
    casos_de_prueba = [" MMMCMLXXXVI", "viii", "XLIV", "clxx  ", "MCDL"]
    
    for caso in casos_de_prueba:
        resultado = traductor.romano_entero(caso)
        # Formateamos la salida para ver la limpieza de datos en acción
        print(f"Original: '{caso}' -> Limpio y Procesado: {resultado}")
# Out:
# === 🏛️ Conversor Romano Pro ===
# Original: ' MMMCMLXXXVI' -> Limpio y Procesado: 3986
# Original: 'viii' -> Limpio y Procesado: 8
# Original: 'XLIV' -> Limpio y Procesado: 44
# Original: 'clxx  ' -> Limpio y Procesado: 170
# Original: 'MCDL' -> Limpio y Procesado: 1450

# %% [markdown]
# ## 🔍 Explicación de la Versión Profesional
#
# En el código anterior transformamos un algoritmo funcional en **Software Robusto**. ¿Qué mejoras implementamos en nuestra clase `ConversorRomanoPro`?
#
# 1. **Limpieza de Datos Preventiva (`.upper().strip()`):** Los usuarios cometen errores. Si alguien ingresa `" viii "` (con minúsculas y espacios), la versión básica colapsaría al no encontrar la `'v'` minúscula en el diccionario. Al aplicar `.upper()` (convertir a mayúsculas) y `.strip()` (eliminar espacios a los lados) apenas entra el dato, protegemos nuestro ciclo `while` de errores fatales.
#
# 2. **Atributos Internos / Encapsulamiento (`self._valores`):**
#    Al poner un guion bajo antes del nombre del diccionario, estamos usando una convención de Python que le dice a otros programadores: *"Este atributo es privado, es solo para uso interno de la clase. Por favor, no lo modifiques desde afuera"*.
#
# 3. **Type Hinting y Docstrings:**
#    Definimos exactamente qué espera el método (`romano: str`) y qué promete devolver (`-> int`). Además, agregamos el "manual de usuario" (Docstring) debajo de cada definición, una práctica obligatoria en equipos de desarrollo profesionales.
#
# 4. **Testing Automatizado:**
#    Al usar el bloque `if __name__ == "__main__":`, creamos un entorno de pruebas seguro. Pasamos una lista de casos extremos (incluyendo minúsculas y espacios) para demostrar visualmente que nuestra validación y limpieza preventiva funcionan a la perfección.

# %% [markdown]
# ---
# # 🔥 Bonus Track: Pilares Avanzados de la POO
#
# Para que este cuaderno sirva como una guía definitiva de Programación Orientada a Objetos, exploraremos mediante ejemplos rápidos los 4 conceptos avanzados que diferencian a un programador junior de uno profesional: **Herencia, Super, Polimorfismo y Propiedades**.
#
# ## 1. Herencia y la función `super()`
#
#
#
# [Image of Object Oriented Programming Inheritance diagram]
#
#
# La **Herencia** nos permite crear una clase nueva (Hija) a partir de una clase existente (Padre). La clase Hija hereda todos los atributos y métodos del Padre, evitando que copiemos y peguemos código.
#
# **`super()`** es la función que le permite a la clase Hija "llamar" a los métodos de su Padre, especialmente a su constructor (`__init__`), para no tener que reescribir la inicialización de variables.

# %%
# 💡 Ejemplo de Herencia y Super

# 1. Clase Padre (Base)
class Vehiculo:
    def __init__(self, marca, modelo):
        self.marca = marca
        self.modelo = modelo
        
    def arrancar(self):
        return f"El {self.marca} {self.modelo} está en marcha."

# 2. Clase Hija (Hereda de Vehiculo)
class AutoElectrico(Vehiculo):
    def __init__(self, marca, modelo, bateria):
        # Usamos super() para que el Padre inicialice la marca y el modelo
        super().__init__(marca, modelo)
        # Inicializamos el atributo exclusivo del hijo
        self.bateria = bateria 
        
    # Método exclusivo de la clase hija
    def cargar_bateria(self):
        return f"Cargando la batería de {self.bateria} kWh..."

# --- Prueba ---
mi_tesla = AutoElectrico("Tesla", "Model 3", 75)

# Puede usar métodos heredados del Padre:
print(mi_tesla.arrancar()) 

# Y métodos propios:
print(mi_tesla.cargar_bateria())
# Out:
# El Tesla Model 3 está en marcha.
# Cargando la batería de 75 kWh...

# %% [markdown]
# ## 2. Polimorfismo
#
#
#
# La palabra significa "muchas formas". En Python, el **Polimorfismo** ocurre cuando distintas clases tienen un método con el **mismo nombre**, pero cada una lo ejecuta a su propia manera.
#
# Esto nos permite tratar a diferentes objetos de la misma forma sin preocuparnos de qué clase exacta provienen.

# %%
# 💡 Ejemplo de Polimorfismo

class Perro:
    def hacer_sonido(self):
        return "¡Guau!"

class Gato:
    def hacer_sonido(self):
        return "¡Miau!"

class Pato:
    def hacer_sonido(self):
        return "¡Cuac!"

# Tenemos una lista con objetos de DIFERENTES clases
animales = [Perro(), Gato(), Pato()]

# Gracias al Polimorfismo, no necesitamos saber qué animal es.
# Todos entienden la instrucción "hacer_sonido()", pero responden distinto.
print("Concierto de animales:")
for animal in animales:
    print(animal.hacer_sonido())
# Out:
# Concierto de animales:
# ¡Guau!
# ¡Miau!
# ¡Cuac!

# %% [markdown]
# ## 3. Propiedades (`@property` y Encapsulamiento)
#
# En programación profesional, **no deberíamos permitir que nadie modifique los atributos de un objeto directamente** (ej. `mi_cuenta.saldo = -5000`), ya que podrían romper la lógica de negocio introduciendo valores inválidos.
#
# Para protegerlos, Python usa **Propiedades**. Convertimos el atributo en "privado" (poniéndole un guion bajo al inicio `_atributo`) y usamos los decoradores `@property` (para leer) y `@atributo.setter` (para modificar bajo nuestras propias reglas).

# %%
# 💡 Ejemplo de Propiedades (Protegiendo los datos)

class Empleado:
    def __init__(self, nombre, salario_inicial):
        self.nombre = nombre
        # El guion bajo indica que _salario es de uso interno (privado)
        self._salario = salario_inicial 

    # 1. Getter: Permite leer el salario de forma segura
    @property
    def salario(self):
        return self._salario

    # 2. Setter: Reglas estrictas para poder modificar el salario
    @salario.setter
    def salario(self, nuevo_monto):
        if nuevo_monto < 0:
            raise ValueError("Error de sistema: El salario no puede ser negativo.")
        elif nuevo_monto < self._salario:
            print("Advertencia: Se está reduciendo el salario del empleado.")
            self._salario = nuevo_monto
        else:
            print("¡Aumento aprobado!")
            self._salario = nuevo_monto

# --- Prueba ---
dev = Empleado("Ana", 1500)

# Leemos el salario (Usa el @property)
print(f"Salario inicial: ${dev.salario}")

# Intentamos modificarlo de forma válida (Usa el @salario.setter)
dev.salario = 2000 
print(f"Nuevo salario: ${dev.salario}")

# Si intentamos poner un salario ilógico, el Setter nos protegerá
try:
    dev.salario = -500
except ValueError as e:
    print(f"Intento fallido: {e}")
# Out:
# Salario inicial: $1500
# ¡Aumento aprobado!
# Nuevo salario: $2000
# Intento fallido: Error de sistema: El salario no puede ser negativo.

# %% [markdown]
# ## 📚 Glosario de Programación Orientada a Objetos (POO)
#
#
#
# Para consolidar todo lo aprendido en este cuaderno y en el Bonus Track, aquí tienes las definiciones formales de los conceptos clave de la Programación Orientada a Objetos que hemos aplicado:
#
# * **Atributos:** Propiedades o características de una clase que almacenan datos y definen el estado de un objeto. En Python, se definen dentro de una clase y se accede a ellos mediante instancias (Ej. `self.valores` o `self.marca`).
# * **Clases:** Plantillas o planos para crear objetos. Una clase define un conjunto de atributos y métodos que caracterizan a cualquier objeto creado a partir de ella (Ej. `class Conversion:`).
# * **Constructores:** Métodos especiales en una clase que se ejecutan automáticamente al crear un nuevo objeto. En Python, el constructor se define mediante el método `__init__`, el cual inicializa los atributos del objeto.
# * **Herencia:** Mecanismo que permite a una clase derivada (hija) heredar atributos y métodos de una clase base (padre), promoviendo la reutilización de código y la creación de jerarquías de clases (Ej. `class AutoElectrico(Vehiculo):`).
# * **Métodos:** Funciones definidas dentro de una clase que describen los comportamientos o acciones que un objeto puede realizar (Ej. `def romano_entero(self, romano):`). Los métodos pueden manipular los atributos de un objeto y realizar operaciones específicas.
# * **Objetos:** Instancias de una clase que representan entidades concretas en programación orientada a objetos. Los objetos tienen atributos y métodos definidos por la clase que les dio origen (Ej. `numero = Conversion()`).
# * **Polimorfismo:** Capacidad de diferentes clases para ser tratadas como instancias de una misma clase a través de una interfaz común. Permite que un mismo método pueda tener diferentes comportamientos según el objeto que lo invoque (Ej. el método `hacer_sonido()` en perros, gatos y patos).
# * **Propiedades:** Mecanismo en Python (usando decoradores como `@property` y `@atributo.setter`) que permite controlar el acceso a los atributos de una clase, proporcionando métodos para obtener, establecer o eliminar el valor de un atributo de manera segura y controlada.
# * **Self:** Parámetro especial y obligatorio en los métodos de una clase en Python. Se refiere a la instancia actual del objeto, permitiendo acceder a sus propios atributos y métodos desde dentro de la clase.
# * **Super:** Función en Python (`super()`) que permite acceder a métodos y atributos de una clase padre desde una clase hija, facilitando la reutilización de código y la correcta inicialización durante la herencia.

# %% [markdown]
# # 🎉 Conclusión del Cuaderno: Arquitectura de Software con POO
#
# ¡Has superado el último, más abstracto y más poderoso concepto de este bloque de Fundamentos de Python!
#
# La **Programación Orientada a Objetos (POO)** requiere una forma de pensar diferente: pasamos de dar "órdenes sueltas" a la computadora, a diseñar un ecosistema de objetos que interactúan entre sí. Este es exactamente el paradigma bajo el cual están construidas las librerías líderes de Ciencia de Datos como Pandas, Scikit-Learn y TensorFlow.
#
# ### 🧠 Resumen de tus nuevos superpoderes:
#
# * **Abstracción y Encapsulamiento:** Eres capaz de modelar conceptos lógicos (como el `ConversorRomano`) empaquetando sus métodos y atributos en un solo lugar, manteniendo el código ordenado.
# * **Inicialización Segura:** Sabes utilizar `__init__` y `self` para garantizar que tus objetos nazcan listos para funcionar desde el primer milisegundo.
# * **Escalabilidad (Bonus Track):** Comprendes cómo reutilizar código de manera masiva mediante la **Herencia** y `super()`, cómo flexibilizar procesos con el **Polimorfismo**, y cómo proteger datos críticos usando **Propiedades**.
# * **Vocabulario Técnico:** Con el glosario integrado, ahora cuentas con la terminología exacta que los reclutadores buscan en las entrevistas técnicas de ingeniería de datos y software.
#
# ---
# **🏆 ¡Felicidades por completar el Tema 4!** Con esta base sólida de estructuras de datos, control de flujo, funciones y programación orientada a objetos, tu lógica algorítmica está más que afilada. Estás completamente listo/a para avanzar al **Siguiente Tema:** Pandas; Dataframes, lectura y exportación de archivos.
