# %% [markdown]
# # 📘 Fundamentos de Python: Estructuras de Datos y Algoritmos Básicos
#
# ¡Bienvenido/a a este cuaderno de estudio interactivo!
#
# Este documento está diseñado para servir como una guía de referencia rápida y práctica sobre los bloques de construcción fundamentales en Python. A través de explicaciones teóricas y ejemplos de código ejecutables, dominaremos cómo almacenar, organizar y manipular información.
#
# ## 🚀 Contenido del Cuaderno
#
# 1.  **Cadenas de Texto (Strings):** Manipulación, formateo y métodos esenciales.
# 2.  **Listas (Lists):** Colecciones ordenadas y mutables.
# 3.  **Diccionarios (Dictionaries):** Almacenamiento eficiente clave-valor.
# 4.  **Tuplas (Tuples):** Datos inmutables y optimización de memoria.
# 5.  **Comparativa:** Cuadro resumen para saber cuándo usar cada estructura.
# 6.  **Ejercicio Práctico:** Desarrollo de un algoritmo "Contador de Palabras" (lógica manual).
# 7.  **Nivel Pro:** Refactorización del ejercicio usando la librería `collections.Counter`.
#
# ---
# > **Instrucciones:** Ejecuta las celdas de código (Code) paso a paso para ver los resultados. Lee las celdas de texto (Markdown) para entender la lógica detrás de cada operación.

# %% [markdown]
# ## 1. Cadenas de Texto (Strings)
# Las cadenas son secuencias de caracteres. En Python son **inmutables**, lo que significa que no puedes cambiar un carácter individual una vez creada la cadena.

# %%
# Definición
mensaje = "Hola, Mundo de Python"

# Métodos comunes
print(mensaje.upper())      # TODO EN MAYÚSCULAS
print(mensaje.lower())      # todo en minúsculas
print(mensaje.split(","))   # Divide la cadena en una lista: ['Hola', ' Mundo de Python']
print(mensaje[0:4])         # Slicing: 'Hola' (caracteres del 0 al 3)

# Formateo (f-strings)
nombre = "Ariel"
print(f"Bienvenido, {nombre}!")
# Out:
# HOLA, MUNDO DE PYTHON
# hola, mundo de python
# ['Hola', ' Mundo de Python']
# Hola
# Bienvenido, Ariel!

# %% [markdown]
# ## 2. Listas (Lists)
# Las listas son colecciones **ordenadas** y **mutables**. Esto significa que puedes cambiar su contenido (añadir, quitar o modificar elementos) después de haberlas creado.
#
# * **Ordenadas:** Mantienen el orden en que se insertan los elementos.
# * **Mutables:** Permiten modificaciones directas en la memoria.
# * **Flexibles:** Pueden contener diferentes tipos de datos simultáneamente.

# %%
# Definición
frutas = ["manzana", "banana", "cereza"]

# Operaciones
frutas.append("naranja")    # Agrega al final
frutas.insert(1, "uva")     # Agrega en una posición específica
frutas[0] = "manzana roja"  # Modificar un elemento

# Acceso y eliminación
print(frutas[1])            # Acceder al segundo elemento
frutas.pop()                # Elimina el último elemento
del frutas[2]               # Elimina por índice

print(f"Lista final: {frutas}")
# Out:
# uva
# Lista final: ['manzana roja', 'uva', 'cereza']

# %% [markdown]
# ## 3. Diccionarios (Dictionaries)
# Son colecciones de pares **clave-valor**. Son extremadamente rápidos para buscar información porque funcionan mediante un índice basado en llaves únicas.
#
# * **Clave-Valor:** Cada dato tiene una etiqueta única.
# * **Mutables:** Puedes añadir o cambiar elementos.

# %%
# Definición
usuario = {
    "nombre": "Elena",
    "edad": 25,
    "ciudad": "Madrid"
}

# Acceso y Modificación
print(usuario["nombre"])    # Acceder por clave
usuario["edad"] = 26        # Actualizar valor
usuario["profesion"] = "Ingeniera" # Agregar nueva clave-valor

# Métodos útiles
print(usuario.keys())       # Obtener todas las claves
print(usuario.values())     # Obtener todos los valores
print(usuario.items())      # Obtener pares (clave, valor)

# %% [markdown]
# ## 4. Tuplas (Tuples)
# Las tuplas son secuencias de elementos similares a las listas, pero con una diferencia fundamental: son **inmutables**. Una vez creada, no puedes cambiar sus elementos.
#
# * **Inmutables:** Ideales para datos que no deben cambiar (coordenadas, constantes).
# * **Eficientes:** Consumen menos memoria que las listas.

# %%
# Definición (usa paréntesis)
coordenadas = (10.5, 20.8)

# Características
print(coordenadas[0])       # Acceso igual que las listas
# coordenadas[0] = 15.0     # ¡ESTO DARÍA ERROR! Las tuplas no se pueden modificar

# Desempaquetado de tuplas
x, y = coordenadas
print(f"X: {x}, Y: {y}")

# %% [markdown]
# ### Resumen Comparativo de Estructuras de Datos
#
# | Estructura | Símbolo | ¿Mutable? | ¿Ordenada? | Uso común |
# | :--- | :---: | :---: | :---: | :--- |
# | **Lista** | `[]` | Sí | Sí | Colecciones de elementos que cambian con frecuencia. |
# | **Diccionario** | `{}` | Sí | No* | Almacenar datos con etiquetas (pares clave-valor). |
# | **Tupla** | `()` | No | Sí | Datos constantes o configuraciones fijas. |
# | **Cadena** | `""` | No | Sí | Almacenamiento y manipulación de texto. |
#
# > **Nota:** A partir de Python 3.7+, los diccionarios mantienen el orden de inserción como un detalle de implementación, pero su propósito principal sigue siendo el acceso mediante claves.

# %% [markdown]
# # 📌 Resumen de Conceptos Clave
#
# En Python, elegir la estructura de datos adecuada depende de lo que necesites hacer con la información. Aquí tienes la regla de oro para decidir:
#
# * **¿Necesitas cambiar los datos constantemente?** Usa una `Lista`.
# * **¿Los datos son fijos y no deben alterarse?** Usa una `Tupla`.
# * **¿Quieres buscar datos por una etiqueta o nombre en lugar de una posición?** Usa un `Diccionario`.
# * **¿Estás trabajando exclusivamente con texto?** Usa una `Cadena`.
#
# ### 💡 Tips Pro para Jupyter:
# 1.  Usa `type(variable)` para verificar qué estructura estás usando.
# 2.  Usa `len(variable)` para saber cuántos elementos contiene.
# 3.  Presiona `Shift + Tab` dentro de los paréntesis de un método (como `.append()`) para ver la documentación rápida.
#
# ---
# **¡Felicidades!** Ya tienes una base sólida sobre el manejo de datos en Python.

# %% [markdown]
# ## 📝 Ejercicio Práctico: Contador de Palabras
#
# **Consigna:**
# Desarrolle un programa en Python donde, dado un texto proporcionado por el usuario, se encargue de imprimir el número de veces que cada palabra se repite. Para ello, investigue sobre la utilización del comando `input`.
#
# **Requerimientos del código:**
# * Utilizar un diccionario almacenado en la variable `conteo`.
# * Las **claves** deben contener las palabras.
# * Los **valores** deben ser números enteros que representen el número de instancias.
#
# **Caso de prueba:**
# > “El amor es una locura que ni el cura lo cura porque si el cura lo cura sería una locura del cura”
#
# **Resultado esperado:**
# * La palabra ' El ' se repite 1 instancia(s)
# * La palabra ' amor ' se repite 1 instancia(s)
# * La palabra ' es ' se repite 1 instancia(s)
# * La palabra ' una ' se repite 2 instancia(s)
# * La palabra ' locura ' se repite 2 instancia(s)
# * La palabra ' que ' se repite 1 instancia(s)
# * La palabra ' ni ' se repite 1 instancia(s)
# * La palabra ' el ' se repite 2 instancia(s)
# * La palabra ' cura ' se repite 5 instancia(s)
# * La palabra ' lo ' se repite 2 instancia(s)
# * La palabra ' porque ' se repite 1 instancia(s)
# * La palabra ' si ' se repite 1 instancia(s)
# * La palabra ' sería ' se repite 1 instancia(s)
# * La palabra ' del ' se repite 1 instancia(s)

# %%
texto = input("Escribe una frase: ")
conteo = {}

# comience su código aquí:
# dividir texto en palabras
palabras = texto.split()

#contar las instancias
for palabra in palabras:
        if palabra in conteo:
            conteo[palabra] += 1 
        else:
             conteo[palabra] = 1 
# imprimir el conteo de cada palabra 
for palabra, cantidad in conteo.items():
    print (f"La palabra'{palabra}' se repite {cantidad} instancia*(s)")
# Out:
# Escribe una frase:  El amor es una locura que ni el cura lo cura porque si el cura lo cura sería una locura del cura
# La palabra'El' se repite 1 instancia*(s)
# La palabra'amor' se repite 1 instancia*(s)
# La palabra'es' se repite 1 instancia*(s)
# La palabra'una' se repite 2 instancia*(s)
# La palabra'locura' se repite 2 instancia*(s)
# La palabra'que' se repite 1 instancia*(s)
# La palabra'ni' se repite 1 instancia*(s)
# La palabra'el' se repite 2 instancia*(s)
# La palabra'cura' se repite 5 instancia*(s)
# La palabra'lo' se repite 2 instancia*(s)
# La palabra'porque' se repite 1 instancia*(s)
# La palabra'si' se repite 1 instancia*(s)
# La palabra'sería' se repite 1 instancia*(s)
# La palabra'del' se repite 1 instancia*(s)

# %% [markdown]
# ## 🔍 Explicación del Algoritmo
#
# El programa sigue una lógica de **procesamiento, almacenamiento y visualización** de datos. A continuación, se detalla qué hace cada parte del código:
#
# 1.  **Captura de datos (`input`)**: Se solicita al usuario una cadena de texto y se almacena en la variable `texto`.
# 2.  **Tokenización (`split`)**: El método `.split()` divide la cadena de texto en elementos individuales cada vez que encuentra un espacio en blanco, creando una **lista** llamada `palabras`.
# 3.  **Lógica de Conteo (Bucle `for` y Diccionario)**:
#     * Se inicializa un diccionario vacío llamado `conteo`.
#     * Iteramos sobre la lista de palabras. Para cada palabra:
#         * Si la palabra **ya existe** como clave en el diccionario, se le suma 1 a su valor actual (`conteo[palabra] += 1`).
#         * Si la palabra **no existe**, se crea la clave y se inicializa con el valor 1.
# 4.  **Visualización de resultados**: Se utiliza el método `.items()` para recorrer el diccionario y extraer tanto la **clave** (la palabra) como el **valor** (la cantidad de repeticiones), imprimiéndolos con un formato amigable usando una `f-string`.
#
# ---

# %% [markdown]
# ## 🚀 Versión Profesional: Usando `collections.Counter`
#
# En proyectos reales, en lugar de gestionar el conteo manualmente con bucles `if/else`, utilizamos la librería estándar de Python. `Counter` es una subclase de diccionario diseñada específicamente para contar objetos.
#
# ### Ventajas:
# * **Legibilidad:** El código es mucho más corto.
# * **Rendimiento:** Está optimizado internamente en C.
# * **Funcionalidad extra:** Permite obtener fácilmente los elementos más comunes o realizar operaciones matemáticas entre conteos.

# %%
from collections import Counter

# 1. Entrada de usuario
texto = input("Escribe una frase: ")

# 2. Limpieza básica y división (opcional: .lower() para no distinguir mayúsculas)
palabras = texto.lower().split()

# 3. El "truco" profesional: Counter hace todo el trabajo de conteo en una línea
conteo = Counter(palabras)

# 4. Impresión elegante
print("-" * 30)
for palabra, cantidad in conteo.items():
    print(f"La palabra '{palabra.capitalize()}' se repite {cantidad} instancia(s)")

# Bonus: ¿Cuál es la palabra que más se repite?
mas_comun = conteo.most_common(1)
print(f"\n🏆 La palabra más frecuente es: '{mas_comun[0][0]}' con {mas_comun[0][1]} veces.")

# %% [markdown]
# ## 🔍 Explicación de la Versión Profesional (`Counter`)
#
# Esta versión optimizada utiliza herramientas avanzadas de la biblioteca estándar de Python para lograr un código más limpio y eficiente:
#
# 1. **Importación de `Counter`**: Se trae la clase `Counter` del módulo `collections`. Esta es una herramienta especializada que recibe un iterable (como una lista de palabras) y devuelve un diccionario donde las llaves son los elementos y los valores son sus frecuencias.
# 2. **Normalización (`.lower()`)**: Al usar `texto.lower()`, convertimos todo a minúsculas antes de contar. Esto evita que el programa cuente "El" y "el" como palabras distintas, logrando un conteo más preciso.
# 3. **Abstracción del Conteo**: A diferencia del método manual, donde usamos un bucle `for` y validaciones `if/else`, `Counter(palabras)` realiza toda la lógica de validación e incremento internamente en una sola línea.
# 4. **Métodos Especializados**:
#     * `.items()`: Al igual que un diccionario normal, nos permite iterar sobre los pares palabra-cantidad.
#     * `.most_common(n)`: Es una función exclusiva de `Counter` que ordena automáticamente los resultados de mayor a menor y devuelve los `n` elementos más frecuentes.
#
# ---
